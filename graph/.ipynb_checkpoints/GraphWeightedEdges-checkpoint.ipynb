# %%
import networkx as nx
import pandas as pd
import similarity as sm

# %%
G = nx.Graph()
docs = sm.compute_similarity("../keywords/linalg_desclinks.json")
# Out:
# titles ['Linear algebra', 'Geometry', 'Line (geometry)', 'Plane (geometry)', 'Rotation (mathematics)', 'Functional analysis', 'Engineering', 'Mathematical model', 'Nonlinear system', 'Matrix (mathematics)', 'Vector space', 'Linear map', 'Mathematics', 'Linear equation', 'Length', 'Area', 'Volume', 'Mathematical sciences', 'Axiomatic system', 'Euclid', "Euclid's Elements", 'Middle Ages', 'René Descartes', 'Pierre de Fermat', 'Non-Euclidean geometry', 'Topological manifold', 'Ancient Greek', 'Mathematics', 'List of geometers', 'Axiom', 'Primitive notion', 'Differential geometry', 'Geodesic', 'Projective geometry', 'Analytic geometry', 'Linear equation', 'Incidence geometry', 'Euclid', 'Axiom', 'Euclidean geometry', 'Non-Euclidean geometry', 'Projective geometry', 'Affine geometry', 'Curvature', 'Euclidean space', 'Geometry', 'Trigonometry', 'Graph theory', 'Graph of a function', 'Mathematics', 'Dimension', 'Surface (topology)', 'Two-dimensional space', 'Point (geometry)', 'Line (geometry)', 'Three-dimensional space', 'Euclidean geometry', 'Map (mathematics)', 'Group (mathematics)', 'Function composition', 'Mechanics', 'Physics', 'Coordinate system', 'Orthonormal basis', 'Frame of reference', 'Clockwise', 'Active and passive transformation', 'Mathematics', 'Geometry', 'Motion (geometry)', 'Space (mathematics)', 'Point (geometry)', 'Rigid body', 'Translation (geometry)', 'Reflection (mathematics)', 'Flat (geometry)', 'Dimension', 'Dimension (vector space)', 'Linear algebra', 'Measure (mathematics)', 'Integral', 'Probability', 'Functional (mathematics)', 'Calculus of variations', 'Higher-order function', 'Jacques Hadamard', 'Vito Volterra', 'Maurice René Fréchet', 'Paul Lévy (mathematician)', 'Frigyes Riesz', 'Lwów School of Mathematics', 'Poland', 'Stefan Banach', 'Mathematical analysis', 'Vector space', 'Inner product space', 'Norm (mathematics)', 'Topological space', 'Linear map', 'Function space', 'Fourier transform', 'Continuous function', 'Unitary operator', 'Differential equation', 'Integral equation', 'Latin', 'Science', 'Empirical evidence', 'Innovation', 'Design', 'Construction', 'Maintenance (technical)', 'Structure', 'Machine', 'Material', 'System', 'Process', 'Organization', 'List of engineering branches', 'Applied mathematics', 'Applied science', 'Glossary of engineering', 'System', 'Mathematics', 'Language of mathematics', 'Natural science', 'Physics', 'Biology', 'Earth science', 'Chemistry', 'Engineering', 'Computer science', 'Artificial intelligence', 'Social science', 'Economics', 'Psychology', 'Sociology', 'Political science', 'Physicist', 'Mathematician', 'Engineer', 'Statistician', 'Operations research', 'Economist', 'Wikipedia:Citation needed', 'Linearization', 'Soliton', 'Chaos theory', 'Singularity (mathematics)', 'Randomness', 'Equation', 'Differential equation', 'Polynomial', 'Function (mathematics)', 'Linear combination', 'Variable (mathematics)', 'Function (mathematics)', 'Mathematics', 'Outline of physical science', 'System', 'Proportionality (mathematics)', 'Engineer', 'Physicist', 'Mathematician', 'Scientist', 'Dynamical system', 'Linear system', 'Numerical analysis', 'Matrix (mathematics)', 'Sparse matrix', 'Diagonal matrix', 'Finite element method', 'Derivative', 'Taylor series', 'Physics', 'Classical mechanics', 'Optics', 'Electromagnetism', 'Quantum mechanics', 'Quantum electrodynamics', 'Rigid body dynamics', 'Computer graphics', '3D modeling', 'Glossary of computer graphics', 'Probability theory', 'Statistics', 'Stochastic matrix', 'PageRank', 'Matrix calculus', 'Mathematical analysis', 'Derivative', 'Exponential function', 'Economics', 'Matrix addition', 'Conformable matrix', 'Matrix multiplication', 'Matrix multiplication', 'Scalar (mathematics)', 'Field (mathematics)', 'Linear map', 'Linear function', 'Rotation (mathematics)', 'Euclidean vector', 'Dimension', 'Rotation matrix', 'Row and column vectors', 'Position (vector)', 'Transformation matrix', 'Function composition', 'Transformation (fun ...
# length before 91809
# length after 45369
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
docs
# Out:
# [('Organization', 'Axiom', {'similarity': 0.076099051896885969}),
#  ('Clockwise', 'Algebraic equation', {'similarity': 0.041378639476793308}),
#  ('Linear system', 'Topological space', {'similarity': 0.05558998885287552}),
#  ('Soliton', 'Statistics', {'similarity': 0.099418188220210868}),
#  ('Morphism', 'Linear regression', {'similarity': 0.086422440689225971}),
#  ('Determinant', 'Two-dimensional space', {'similarity': 0.16850949363209933}),
#  ('Axiomatic system', 'Pierre de Fermat', {'similarity': 0.11152154514311244}),
#  ('Euclidean geometry', 'PageRank', {'similarity': 0.071006363963399904}),
#  ('Matrix (mathematics)',
#   'Pierre de Fermat',
#   {'similarity': 0.063356816731694354}),
#  ('Scalar (mathematics)', 'Equation', {'similarity': 0.082071514238139562}),
#  ('Plane (geometry)',
#   'Surface (topology)',
#   {'similarity': 0.31814273678300947}),
#  ('Real number', 'Chaos theory', {'similarity': 0.13112344980183685}),
#  ('Mathematician', 'Trigonometry', {'similarity': 0.14136205255574327}),
#  ('Differential equation',
#   'Constant term',
#   {'similarity': 0.055295730872826264}),
#  ('Exponential function', 'Poland', {'similarity': 0.096548602729178867}),
#  ('Fourier series', 'Linear system', {'similarity': 0.12197497485466492}),
#  ('Jacques Hadamard', 'Function space', {'similarity': 0.040209614861251922}),
#  ('Social science',
#   'Differential geometry',
#   {'similarity': 0.087392074428355226}),
#  ('Term (logic)', 'Clockwise', {'similarity': 0.086395153947660175}),
#  ('Curvature', 'Geometry', {'similarity': 0.16410594470988057}),
#  ('René Descartes', 'Linear regression', {'similarity': 0.062506780420521477}),
#  ('Machine', 'Earth science', {'similarity': 0.071407487350818769}),
#  ('Mathematical analysis',
#   'Coordinate-free',
#   {'similarity': 0.14914673136750012}),
#  ('Natural science',
#   'Incidence geometry',
#   {'similarity': 0.063351655814449112}),
#  ('Linearization', 'Invertible matrix', {'similarity': 0.13141595958256994}),
#  ('System of linear equations',
#   'Topology',
#   {'similarity': 0.10951256612850913}),
#  ('Banach space', 'Computer science', {'similarity': 0.023632153566708326}),
#  ('Ring (mathematics)',
#   'Numerical analysis',
#   {'similarity': 0.069099835380103461}),
#  ('Abstract algebra',
#   'Rigid body dynamics',
#   {'similarity': 0.077781502561010685}),
#  ('System of linear equations', 'Axiom', {'similarity': 0.13062236165079488}),
#  ('Endomorphism',
#   'Glossary of engineering',
#   {'similarity': 0.021393444124743539}),
#  ('Axiomatic system', 'Linearization', {'similarity': 0.18678775401312664}),
#  ('Electromagnetism', 'Matrix addition', {'similarity': 0.01563625803948103}),
#  ('Trigonometry', 'Topological space', {'similarity': 0.048523963697008433}),
#  ('Integral', 'Chemistry', {'similarity': 0.061419919901565805}),
#  ('Morphism', 'Category theory', {'similarity': 0.55380922033889923}),
#  ('Manifold', 'Maurice René Fréchet', {'similarity': 0.1033266973590099}),
#  ('René Descartes', 'Primitive notion', {'similarity': 0.036212997334934736}),
#  ('Nonlinear system', 'Graph theory', {'similarity': 0.089366093797278279}),
#  ('Fourier transform',
#   'Translation (geometry)',
#   {'similarity': 0.1031876853026676}),
#  ('Higher-order function',
#   'Banach space',
#   {'similarity': 0.17240732166907274}),
#  ('Glossary of engineering',
#   'Calculus of variations',
#   {'similarity': 0.031059336105375528}),
#  ('Glossary of computer graphics', 'Stochastic matrix', {'similarity': 0.0}),
#  ('Topological manifold', 'Frigyes Riesz', {'similarity': 0.0}),
#  ('Applied mathematics',
#   'Function space',
#   {'similarity': 0.033100207857575489}),
#  ('Constant term', 'Hilbert space', {'similarity': 0.060120937973887206}),
#  ('Geometry', 'Geodesic', {'similarity': 0.30355523221663216}),
#  ('Physics', 'Abstract algebra', {'similarity': 0.19501839463529613}),
#  ('Space (mathematics)',
#   'Linear equation',
#   {'similarity': 0.14504776826287294}),
#  ('Probability theory', 'Frigyes Riesz', {'similarity': 0.063119883633964563}),
#  ('Optics', 'Matrix multiplication', {'similarity': 0.0}),
#  ('Sparse matrix',
#   'Language of mathematics',
#   {'similarity': 0.059770793405199973}),
#  ('Process', 'Innovation', {'similarity': 0.0}),
#  ('Matrix calculus', 'Mathematician', {'similarity': 0.10005404807510242}),
#  ('Natural science', 'Affine geometry', {'similarity': 0.055457466571735663}),
#  ('System of linear equations',
#   'Non-Euclidean geometry',
#   {'similarity': 0.099015547241073101}),
#  ('0', 'Geodesic', {'similarity': 0.082055182735675483}),
#  ('Nonlinear system', 'Natural science', {'similarity': 0.10676178228791977}),
#  ('Quantum electrodynamics', 'Equation', {'similarity': 0.14059025541512479}),
#  ('Module homomorphism', 'Endomorphism', {'similarity': 0.33870840116989187}),
#  ('Active and passive transformation',
#   'Stochastic matrix',
#   {'similarity': 0.096600886298761776}),
#  ('Rational number', 'Topological manifold', {'similarity': 0.0}),
#  ('List of geometers', 'Quantum mechanics', {'similarity': 0.0}),
#  ('Frigyes Riesz',
#   'Module (mathematics)',
#   {'similarity': 0.018504443410118008}),
#  ('Topological manifold', 'Translation (geometry)', {'similarity': 0.0}),
#  ('Maurice René Fréchet',
#   'Applied mathematics',
#   {'similarity': 0.074549689371134445}),
#  ('Biology', 'Linear system', {'similarity': 0.114239705064898}),
#  ("Euclid's Elements", 'Geodesic', {'similarity': 0.094827668148558156}),
#  ('Empirical evidence', 'Area', {'similarity': 0.030171395135049538}),
#  ('Plane (geometry)',
#   'Exponential function',
#   {'similarity': 0.12743244172891557}),
#  ('Non-Euclidean geometry',
#   'Engineering',
#   {'similarity': 0.049760850689319375}),
#  ('Pierre de Fermat',
#   'Rigid body dynamics',
#   {'similarity': 0.053360139930724387}),
#  ('Mechanics', 'Length', {'similarity': 0.064656170961581313}),
#  ('Maurice René Fréchet',
#   'Social science',
#   {'similarity': 0.17014747075955394}),
#  ('Paul Lévy (mathematician)',
#   'Position (vector)',
#   {'similarity': 0.022819382076561725}),
#  ('PageRank', 'Stochastic matrix', {'similarity': 0.12486940877198019}),
#  ('Wikipedia:Citation needed',
#   'Two-dimensional space',
#   {'similarity': 0.01295314903302407}),
#  ('Function composition',
#   'Category of modules',
#   {'similarity': 0.05717442077956849}),
#  ('Computer graphics',
#   'Plane (geometry)',
#   {'similarity': 0.055434193859341022}),
#  ('Stefan Banach',
#   'Dimension (vector space)',
#   {'similarity': 0.11010646984205104}),
#  ('Function composition', 'Physics', {'similarity': 0.045490510141721979}),
#  ('Primitive notion', 'Equation', {'similarity': 0.028645982793657446}),
#  ('Classical mechanics', 'Curvature', {'similarity': 0.097670256142897274}),
#  ('Map (mathematics)',
#   'Metric (mathematics)',
#   {'similarity': 0.094234619163249295}),
#  ('If and only if', 'Material', {'similarity': 0.087007910274175176}),
#  ('Rigid body dynamics',
#   'Applied mathematics',
#   {'similarity': 0.032710201014025789}),
#  ('Stochastic matrix', 'Rigid body', {'similarity': 0.05999513482747279}),
#  ('Mathematician', 'Norm (mathematics)', {'similarity': 0.034178393186973799}),
#  ('Lwów School of Mathematics',
#   'Matrix addition',
#   {'similarity': 0.014560203707413634}),
#  ('Physics', 'Language of mathematics', {'similarity': 0.096387632049426103}),
#  ('Fourier series', 'Economist', {'similarity': 0.02772598232553531}),
#  ('Design', 'Map (mathematics)', {'similarity': 0.030785532037892735}),
#  ('Diagonal matrix', 'Process', {'similarity': 0.0}),
#  ('Image compression', 'Social science', {'similarity': 0.0}),
#  ('Real number', 'Affine geometry', {'similarity': 0.12303194437969231}),
#  ('Analytic geometry', 'Economics', {'similarity': 0.088506819701092199}),
#  ('Ring (mathematics)', 'Euclid', {'similarity': 0.040002861321501972}),
#  ('Applied mathematics', 'Geometry', {'similarity': 0.090240405978494337}),
#  ('Force', 'Area', {'similarity': 0.062972098819832137}),
#  ('Continuous function',
#   'Singularity (mathematics)',
#   {'similarity': 0.17464916778206729}),
#  ('Constant term', 'Process', {'similarity': 0.0}),
#  ("Euclid's Elements",
#   'Projective geometry',
#   {'similarity': 0.17916255582120691}),
#  ('Wikipedia:Citation needed', 'Tensor', {'similarity': 0.019932018659506341}),
#  ('Construction', 'Image compression', {'similarity': 0.0}),
#  ('Mathematical model',
#   'Axiomatic system',
#   {'similarity': 0.19098626595749041}),
#  ('Innovation', 'Integral equation', {'similarity': 0.019500013423905827}),
#  ('Three-dimensional space',
#   'Probability theory',
#   {'similarity': 0.069367088389118259}),
#  ('Complex number', 'Banach space', {'similarity': 0.19103389568283421}),
#  ('Determinant', 'Soliton', {'similarity': 0.079989308546572699}),
#  ('Linear combination', 'Orthonormal basis', {'similarity': 0.0}),
#  ('Norm (mathematics)',
#   'Scalar multiplication',
#   {'similarity': 0.18932649590962322}),
#  ('Linear function',
#   'Conformable matrix',
#   {'similarity': 0.033626351026760364}),
#  ('Motion (geometry)', 'Complex number', {'similarity': 0.0}),
#  ('Finite element method',
#   'Affine geometry',
#   {'similarity': 0.067323416667040989}),
#  ('Morphism', 'Calculus of variations', {'similarity': 0.28352334564454879}),
#  ('Reflection (mathematics)',
#   'Linear equation',
#   {'similarity': 0.13692994036235709}),
#  ('List of geometers', 'Constant term', {'similarity': 0.0}),
#  ('Operations research',
#   'Artificial intelligence',
#   {'similarity': 0.41547649029291012}),
#  ('Graph theory',
#   'Active and passive transformation',
#   {'similarity': 0.036845422443534524}),
#  ('Two-dimensional space',
#   'Quantum mechanics',
#   {'similarity': 0.090678820733849017}),
#  ('Euclidean space', 'Linear algebra', {'similarity': 0.28269178986979693}),
#  ('Structure', 'Jacques Hadamard', {'similarity': 0.049715611024452995}),
#  ('Glossary of engineering',
#   'Natural science',
#   {'similarity': 0.055182212437807451}),
#  ('Taylor series', 'List of geometers', {'similarity': 0.0}),
#  ('Lwów School of Mathematics',
#   'Statistician',
#   {'similarity': 0.10235215965551545}),
#  ('Randomness', 'Length', {'similarity': 0.039246235183127927}),
#  ('Banach space', 'Axiom', {'similarity': 0.054617812320469292}),
#  ("Euclid's Elements",
#   'Scalar multiplication',
#   {'similarity': 0.025152479393540338}),
#  ('Position (vector)', 'Length', {'similarity': 0.10103438124588679}),
#  ('Function (mathematics)',
#   'Linear system',
#   {'similarity': 0.21489957846714741}),
#  ('Variable (mathematics)', 'Curvature', {'similarity': 0.063434968859547275}),
#  ('Ring (mathematics)',
#   'Scalar multiplication',
#   {'similarity': 0.19986554427872943}),
#  ('Lwów School of Mathematics',
#   'Morphism',
#   {'similarity': 0.051305533235809012}),
#  ('Taylor series', 'Statistics', {'similarity': 0.087285931605727812}),
#  ('Curvature', 'Parameter', {'similarity': 0.076832801333052841}),
#  ('Area', 'Parameter', {'similarity': 0.072005704805612636}),
#  ('Term (logic)', 'Space (mathematics)', {'similarity': 0.11672975407511618}),
#  ('Engineering', 'Finite element method', {'similarity': 0.19762587781777166}),
#  ('Mathematical sciences', 'Machine', {'similarity': 0.0}),
#  ('Frigyes Riesz', 'Mathematical sciences', {'similarity': 0.0}),
#  ('Singularity (mathematics)',
#   'Randomness',
#   {'similarity': 0.040698476454453118}),
#  ('Poland', 'Function (mathematics)', {'similarity': 0.08346858415386757}),
#  ('Volume', 'Matrix addition', {'similarity': 0.011362672036021421}),
#  ('Hilbert space', 'Frigyes Riesz', {'similarity': 0.097844285940105455}),
#  ('Material', 'System', {'similarity': 0.085555065555463661}),
#  ('Applied science',
#   'Continuous function',
#   {'similarity': 0.016220760141635104}),
#  ('Nonlinear system', 'Manifold', {'similarity': 0.097792962813600948}),
#  ('Coefficient', 'Real number', {'similarity': 0.069014451104328883}),
#  ('Hilbert space', 'Coordinate system', {'similarity': 0.10922082103355477}),
#  ('Chemistry', 'Empirical evidence', {'similarity': 0.088468613529676193}),
#  ('Linear system', 'Structure', {'similarity': 0.065105450297760784}),
#  ('Ancient Greek', "Euclid's Elements", {'similarity': 0.22695780360499984}),
#  ('Science', 'Topological manifold', {'similarity': 0.0}),
#  ('Integral', 'Frigyes Riesz', {'similarity': 0.10418873176176599}),
#  ('Vito Volterra', 'Orthonormal basis', {'similarity': 0.019621312783719501}),
#  ('Paul Lévy (mathematician)', 'Force', {'similarity': 0.052105474163541589}),
#  ('Length', 'Inner product space', {'similarity': 0.030084862025300842}),
#  ('Sociology', 'Metric (mathematics)', {'similarity': 0.043457138354841385}),
#  ('Dynamical system', 'Rigid body', {'similarity': 0.16069561679836364}),
#  ('Area', 'Dimension', {'similarity': 0.10116816087311233}),
#  ('Dynamical system', 'Function space', {'similarity': 0.24504505736235205}),
#  ('Probability theory',
#   'Norm (mathematics)',
#   {'similarity': 0.086200113224461736}),
#  ('Frame of reference',
#   'René Descartes',
#   {'similarity': 0.063589033993352848}),
#  ('Sociology', 'Surface (topology)', {'similarity': 0.047355196609222015}),
#  ('Outline of physical science',
#   'Differential geometry',
#   {'similarity': 0.075859542014818107}),
#  ('Constant term',
#   'Rigid body dynamics',
#   {'similarity': 0.030899949113279333}),
#  ("Euclid's Elements", 'Equation', {'similarity': 0.086260092805969205}),
#  ('Integral equation', 'Trigonometry', {'similarity': 0.075694809173472266}),
#  ('Linear system', 'Linear algebra', {'similarity': 0.30718900351732892}),
#  ('Banach space', 'Euclidean geometry', {'similarity': 0.094613559578107839}),
#  ('Euclid', 'Map (mathematics)', {'similarity': 0.030646061943702035}),
#  ('Singularity (mathematics)',
#   'Metric (mathematics)',
#   {'similarity': 0.12419497460009578}),
#  ('Linear equation',
#   'Translation (geometry)',
#   {'similarity': 0.084839684036722846}),
#  ('Algebraic equation',
#   'Giuseppe Peano',
#   {'similarity': 0.044219334332171803}),
#  ('Diagonal matrix',
#   'Mathematical analysis',
#   {'similarity': 0.065641246726375224}),
#  ('Calculus of variations',
#   'Graph of a function',
#   {'similarity': 0.25480327273463532}),
#  ('Variable (mathematics)',
#   'Organization',
#   {'similarity': 0.056191279008884897}),
#  ('Parameter', 'Polynomial', {'similarity': 0.12465875432667407}),
#  ('Matrix addition', 'Computer science', {'similarity': 0.059631577367303283}),
#  ('Euclidean geometry', 'Organization', {'similarity': 0.073589598135742215}),
#  ('Pierre de Fermat',
#   'Position (vector)',
#   {'similarity': 0.052489349340237239}),
#  ('Linear combination', 'Transformation (function)', {'similarity': 0.0}),
#  ('Jacques Hadamard', 'Matrix calculus', {'similarity': 0.094502872668767432}),
#  ('Point (geometry)', 'Flat (geometry)', {'similarity': 0.1864951874286416}),
#  ('Outline of physical science',
#   'Wikipedia:Citation needed',
#   {'similarity': 0.043396918210110158}),
#  ('Transformation (function)',
#   'Linear equation',
#   {'similarity': 0.26445347555600057}),
#  ('Plane (geometry)',
#   'Topological space',
#   {'similarity': 0.23938390667783974}),
#  ('Engineer', 'Surface (topology)', {'similarity': 0.030198270226576115}),
#  ('Linearization', 'Euclidean vector', {'similarity': 0.09925590978812171}),
#  ('Dimension (vector space)',
#   'Non-Euclidean geometry',
#   {'similarity': 0.038471721232091111}),
#  ('Metric (mathematics)',
#   'Three-dimensional space',
#   {'similarity': 0.20094869582160987}),
#  ('Primitive notion', 'Engineer', {'similarity': 0.014108162693819705}),
#  ('Topological manifold', 'Economist', {'similarity': 0.0}),
#  ('Lwów School of Mathematics',
#   'Abstract algebra',
#   {'similarity': 0.15425231724420496}),
#  ('Process', 'Economics', {'similarity': 0.0}),
#  ('Transformation matrix', 'Scientist', {'similarity': 0.053397461555320311}),
#  ('Real number', 'Invertible matrix', {'similarity': 0.11952980542171746}),
#  ('Diagonal matrix',
#   'Quantum electrodynamics',
#   {'similarity': 0.050964596558155252}),
#  ("Euclid's Elements",
#   'Rotation (mathematics)',
#   {'similarity': 0.057222382434088927}),
#  ('Calculus of variations',
#   'Norm (mathematics)',
#   {'similarity': 0.14424074179625843}),
#  ('Curvature', 'Optics', {'similarity': 0.092135529243537878}),
#  ('Clockwise', 'Biology', {'similarity': 0.049118745747883358}),
#  ('Frigyes Riesz', 'Unitary operator', {'similarity': 0.062370726343353812}),
#  ('Randomness', 'Complex number', {'similarity': 0.093284396287523941}),
#  ('Topological space',
#   'Mathematical analysis',
#   {'similarity': 0.22301539591645922}),
#  ('Sparse matrix', 'Machine', {'similarity': 0.043476142832216104}),
#  ('Political science',
#   'Measure (mathematics)',
#   {'similarity': 0.055764596018587034}),
#  ('Engineer', 'Topological space', {'similarity': 0.02582663662574939}),
#  ('Function space',
#   'Singularity (mathematics)',
#   {'similarity': 0.11154920183438093}),
#  ('Biology',
#   'Wikipedia:Citation needed',
#   {'similarity': 0.043148162141684335}),
#  ('0', 'Soliton', {'similarity': 0.089391941796842914}),
#  ('Ancient Greek', 'Statistics', {'similarity': 0.068478785560497579}),
#  ('Fourier transform',
#   'Norm (mathematics)',
#   {'similarity': 0.11264658271235831}),
#  ('Variable (mathematics)',
#   'Fourier series',
#   {'similarity': 0.18111872988709804}),
#  ('Image compression', 'Exponential function', {'similarity': 0.0}),
#  ('Map (mathematics)', 'Category theory', {'similarity': 0.2630180880844542}),
#  ('Chemistry', 'Axiom', {'similarity': 0.086465239077168687}),
#  ('Rigid body dynamics',
#   'Linear regression',
#   {'similarity': 0.066333413403487376}),
#  ('Axiomatic system', 'Latin', {'similarity': 0.064611894965206446}),
#  ('Inner product space', 'Chaos theory', {'similarity': 0.062054300355291421}),
#  ('Orthonormal basis', 'Economist', {'similarity': 0.019507813980032214}),
#  ('Topological manifold',
#   'Partial differential equation',
#   {'similarity': 0.0}),
#  ('Primitive notion', 'Rational number', {'similarity': 0.013793901137254214}),
#  ('Computer graphics',
#   'Lwów School of Mathematics',
#   {'similarity': 0.066164859225501735}),
#  ('Row and column vectors', 'Clockwise', {'similarity': 0.026981413813637431}),
#  ('Euclid', 'Statistician', {'similarity': 0.053003184516200862}),
#  ('Linear system', 'Rectangle', {'similarity': 0.029353567907998184}),
#  ('Rotation matrix', 'Sparse matrix', {'similarity': 0.29620697398657908}),
#  ('Structure', 'Incidence geometry', {'similarity': 0.22914877071028086}),
#  ('Economist', 'Axiom', {'similarity': 0.061960706098587628}),
#  ('Proportionality (mathematics)',
#   'Differential geometry',
#   {'similarity': 0.03192189843839173}),
#  ('Algebraic equation',
#   'Variable (mathematics)',
#   {'similarity': 0.26009745952702751}),
#  ('Row and column vectors',
#   'Hilbert space',
#   {'similarity': 0.15254295011715599}),
#  ('Group (mathematics)',
#   'Primitive notion',
#   {'similarity': 0.051348153296791189}),
#  ('Statistician', 'Mathematical model', {'similarity': 0.19210825685489874}),
#  ('Symbol (formal)',
#   'Exponential function',
#   {'similarity': 0.043058280127749544}),
#  ('Machine', 'Natural science', {'similarity': 0.18035260633726385}),
#  ('Euclidean geometry', 'Design', {'similarity': 0.08785540313424918}),
#  ('Field (mathematics)', 'Giuseppe Peano', {'similarity': 0.0}),
#  ('Glossary of engineering',
#   'Randomness',
#   {'similarity': 0.04271333145468225}),
#  ('Transformation matrix',
#   'Norm (mathematics)',
#   {'similarity': 0.12512976338984916}),
#  ('Rational number', 'Giuseppe Peano', {'similarity': 0.051073748622409085}),
#  ('Biology', 'Symbol (formal)', {'similarity': 0.057741891106016602}),
#  ('Giuseppe Peano',
#   'Two-dimensional space',
#   {'similarity': 0.11685192666792006}),
#  ('Physicist', 'Mathematical analysis', {'similarity': 0.16399423042932262}),
#  ('Transformation (function)', 'Latin', {'similarity': 0.064489663458923457}),
#  ('Frame of reference', 'Equation', {'similarity': 0.11421685705803301}),
#  ('Functional (mathematics)',
#   'Constant term',
#   {'similarity': 0.040512862517127088}),
#  ('Optics', 'Jacques Hadamard', {'similarity': 0.097529004761283164}),
#  ('Chaos theory',
#   'Expression (mathematics)',
#   {'similarity': 0.093073998408061534}),
#  ('Rotation matrix',
#   'Functional analysis',
#   {'similarity': 0.080984952981397948}),
#  ('Topology', 'Earth science', {'similarity': 0.055632771896453354}),
#  ('Euclid', 'Coefficient', {'similarity': 0.027609121111553094}),
#  ('Hilbert space', 'Complex number', {'similarity': 0.23854229163977383}),
#  ('Mathematics', 'Exponential function', {'similarity': 0.16338294371998963}),
#  ('Differential geometry',
#   'Flat (geometry)',
#   {'similarity': 0.15590200991012942}),
#  ('Classical mechanics',
#   'Integral equation',
#   {'similarity': 0.099882540476534304}),
#  ('Graph theory', 'René Descartes', {'similarity': 0.054291412808807823}),
#  ('Function space',
#   'Rigid body dynamics',
#   {'similarity': 0.07940706764258737}),
#  ('Area', 'Finite element method', {'similarity': 0.11942251591569938}),
#  ('Pierre de Fermat',
#   'Integral equation',
#   {'similarity': 0.068262770954534632}),
#  ('Rotation (mathematics)',
#   'Paul Lévy (mathematician)',
#   {'similarity': 0.010195850083715175}),
#  ('Dimension (vector space)',
#   'PageRank',
#   {'similarity': 0.042551748692752751}),
#  ('Eigenvalues and eigenvectors',
#   'Unitary operator',
#   {'similarity': 0.13989537230489904}),
#  ('Module (mathematics)',
#   'Giuseppe Peano',
#   {'similarity': 0.030209896540032095}),
#  ('Frigyes Riesz',
#   'Metric (mathematics)',
#   {'similarity': 0.050228813836317845}),
#  ('3D modeling', 'Sociology', {'similarity': 0.10656221642092666}),
#  ('Trigonometry', 'Norm (mathematics)', {'similarity': 0.081977245523247116}),
#  ('Computer science', 'Giuseppe Peano', {'similarity': 0.12250514987378225}),
#  ('Axiomatic system',
#   'Transformation matrix',
#   {'similarity': 0.052536391252113533}),
#  ('Coordinate system', 'Area', {'similarity': 0.076135623589157916}),
#  ('Economics', 'Chaos theory', {'similarity': 0.28703670276757332}),
#  ('Rectangle', 'Higher-order function', {'similarity': 0.013194744495295176}),
#  ('Space (mathematics)',
#   'Empirical evidence',
#   {'similarity': 0.039567794150505313}),
#  ('Incidence geometry',
#   'Operations research',
#   {'similarity': 0.053196415355125835}),
#  ('Soliton', 'Graph of a function', {'similarity': 0.034677923505787682}),
#  ('Engineer', 'Numerical analysis', {'similarity': 0.089770042303000341}),
#  ('Reflection (mathematics)',
#   'Integral equation',
#   {'similarity': 0.039296607708919337}),
#  ('Fourier transform', 'Economics', {'similarity': 0.071511448996896029}),
#  ('Function (mathematics)',
#   'Rigid body dynamics',
#   {'similarity': 0.067295834341885422}),
#  ('Volume', 'Organization', {'similarity': 0.022169307066093852}),
#  ('Functional (mathematics)',
#   'Eigenvalues and eigenvectors',
#   {'similarity': 0.19274413675638835}),
#  ('Function composition',
#   'René Descartes',
#   {'similarity': 0.032764231805508588}),
#  ('Dimension', 'Electromagnetism', {'similarity': 0.12616604381995453}),
#  ('Invertible matrix',
#   'Scalar multiplication',
#   {'similarity': 0.16282479692274507}),
#  ('Continuous function',
#   'Higher-order function',
#   {'similarity': 0.41106525818644141}),
#  ('Metric (mathematics)',
#   'Euclidean vector',
#   {'similarity': 0.14401324824014552}),
#  ('Line (geometry)', '0', {'similarity': 0.095673146678675325}),
#  ('Topology',
#   'Proportionality (mathematics)',
#   {'similarity': 0.049439603927097397}),
#  ('Abstract algebra',
#   'Function composition',
#   {'similarity': 0.13043656121548836}),
#  ('Affine geometry', 'Structure', {'similarity': 0.076846146949540478}),
#  ('Frame of reference', 'Science', {'similarity': 0.12034207172395303}),
#  ('Material', 'Frame of reference', {'similarity': 0.041913420035963822}),
#  ('Optics', 'Space (mathematics)', {'similarity': 0.095558507238666351}),
#  ('Module homomorphism',
#   'Group (mathematics)',
#   {'similarity': 0.14533440090475686}),
#  ('Incidence geometry', 'Linear system', {'similarity': 0.072999439040735262}),
#  ('Partial differential equation',
#   'Construction',
#   {'similarity': 0.060200197969105973}),
#  ('Measure (mathematics)',
#   'Mathematician',
#   {'similarity': 0.047511864636713183}),
#  ('Mathematics', 'René Descartes', {'similarity': 0.18985611023550417}),
#  ('Euclid', 'Curvature', {'similarity': 0.024680887139562631}),
#  ('Latin', 'PageRank', {'similarity': 0.055110957200062566}),
#  ('Matrix multiplication', 'Linear function', {'similarity': 0.0}),
#  ('Vector space', 'Jacques Hadamard', {'similarity': 0.090997142815194262}),
#  ('Lwów School of Mathematics',
#   'Symbol (formal)',
#   {'similarity': 0.019389377111957463}),
#  ('Mathematician', 'Design', {'similarity': 0.15794789865483194}),
#  ('Linear function',
#   'Scalar (mathematics)',
#   {'similarity': 0.32052567349385308}),
#  ('Space (mathematics)', 'Material', {'similarity': 0.054160488724723982}),
#  ('Euclidean vector',
#   'Operations research',
#   {'similarity': 0.063724150067270682}),
#  ('Probability', 'Orthonormal basis', {'similarity': 0.038953782864942985}),
#  ('Artificial intelligence', 'System', {'similarity': 0.28772694468592547}),
#  ('List of engineering branches',
#   'Curvature',
#   {'similarity': 0.0090572725962357326}),
#  ('Continuous function',
#   'Axiomatic system',
#   {'similarity': 0.081878982611425427}),
#  ('Primitive notion',
#   'Functional analysis',
#   {'similarity': 0.041661044949014125}),
#  ('Applied science',
#   'Paul Lévy (mathematician)',
#   {'similarity': 0.093048758954920444}),
#  ('Algebraic equation', 'Engineering', {'similarity': 0.04724140797767714}),
#  ('Polynomial', "Euclid's Elements", {'similarity': 0.050216411607482685}),
#  ('Glossary of computer graphics', 'Psychology', {'similarity': 0.0}),
#  ('Linear combination', 'Earth science', {'similarity': 0.0}),
#  ('Stochastic matrix', 'Tensor', {'similarity': 0.10207297760583768}),
#  ('Mathematics', 'Psychology', {'similarity': 0.0}),
#  ('Chemistry', 'Organization', {'similarity': 0.12709262378394751}),
#  ('Machine', 'Graph of a function', {'similarity': 0.043598434955807987}),
#  ('Determinant', 'Coefficient', {'similarity': 0.17159882498818224}),
#  ('Origin (mathematics)',
#   'Banach space',
#   {'similarity': 0.059378512057915264}),
#  ('Rigid body', 'Sociology', {'similarity': 0.051356498809429676}),
#  ('Latin', 'Three-dimensional space', {'similarity': 0.055137778958016921}),
#  ('Chaos theory', 'Stochastic matrix', {'similarity': 0.18286712530642454}),
#  ('Linear algebra',
#   'Continuous function',
#   {'similarity': 0.20322081808208187}),
#  ('Category theory', 'Topological space', {'similarity': 0.25473137176895644}),
#  ('Dimension', 'Inner product space', {'similarity': 0.13618871289585829}),
#  ('Field (mathematics)', 'Sparse matrix', {'similarity': 0.0}),
#  ('Economist', 'Scientist', {'similarity': 0.13187452947933923}),
#  ('Surface (topology)',
#   'Scalar (mathematics)',
#   {'similarity': 0.081940102387645236}),
#  ('Clockwise', 'Euclidean vector', {'similarity': 0.11731381749105331}),
#  ('Equation', 'PageRank', {'similarity': 0.07394040353909799}),
#  ('Transformation matrix', '0', {'similarity': 0.06608108799358775}),
#  ('Classical mechanics',
#   'Dimension (vector space)',
#   {'similarity': 0.07360108648723851}),
#  ('Linear equation', 'Economics', {'similarity': 0.068473604670752697}),
#  ('Taylor series', 'Linear map', {'similarity': 0.11475399827761686}),
#  ('Axiomatic system',
#   'Analytic geometry',
#   {'similarity': 0.10777475800293355}),
#  ('Integral equation',
#   'Matrix addition',
#   {'similarity': 0.058123838361750564}),
#  ('Functional analysis',
#   'Exponential function',
#   {'similarity': 0.25037524628188601}),
#  ('Space (mathematics)', 'PageRank', {'similarity': 0.058433462141785221}),
#  ('Constant term',
#   'Functional analysis',
#   {'similarity': 0.019863591857218973}),
#  ('Glossary of engineering',
#   'Jacques Hadamard',
#   {'similarity': 0.031924959256021276}),
#  ('Integral', 'Motion (geometry)', {'similarity': 0.0}),
#  ('Quantum electrodynamics', 'Sociology', {'similarity': 0.133295236639177}),
#  ('Social science', 'Length', {'similarity': 0.084003533313254677}),
#  ('Scalar (mathematics)',
#   'Function composition',
#   {'similarity': 0.052640042941981463}),
#  ('Row and column vectors',
#   'Classical mechanics',
#   {'similarity': 0.041934902866295753}),
#  ('Linear combination', 'Rigid body', {'similarity': 0.0}),
#  ('Field (mathematics)', 'Inner product space', {'similarity': 0.0}),
#  ('Exponential function',
#   'Module (mathematics)',
#   {'similarity': 0.056874037841241294}),
#  ('Science', 'Unitary operator', {'similarity': 0.030520668042101792}),
#  ('Tensor', 'Mathematical model', {'similarity': 0.061061583455328132}),
#  ('Jacques Hadamard',
#   'Active and passive transformation',
#   {'similarity': 0.053921328342903557}),
#  ('Morphism', 'Affine geometry', {'similarity': 0.05481623498132672}),
#  ('Clockwise',
#   'Partial differential equation',
#   {'similarity': 0.046006701512246714}),
#  ('Physics', 'Linear system', {'similarity': 0.087875340761217238}),
#  ('Category of modules',
#   'Mathematical model',
#   {'similarity': 0.015699667262941159}),
#  ('Three-dimensional space',
#   'Function composition',
#   {'similarity': 0.14464216581753725}),
#  ('Geodesic', 'Rectangle', {'similarity': 0.094497444933247826}),
#  ('Giuseppe Peano', 'Flat (geometry)', {'similarity': 0.034289719612293747}),
#  ('Ancient Greek', 'Earth science', {'similarity': 0.035715066555717219}),
#  ('Economics', 'Biology', {'similarity': 0.16740130225039479}),
#  ('Jacques Hadamard',
#   'Wikipedia:Citation needed',
#   {'similarity': 0.069709055886038804}),
#  ('Frame of reference', 'Derivative', {'similarity': 0.017032773344798673}),
#  ('3D modeling', 'Graph theory', {'similarity': 0.10063633512662407}),
#  ('Reflection (mathematics)',
#   'Maurice René Fréchet',
#   {'similarity': 0.042989286280540745}),
#  ('Mathematical model', '3D modeling', {'similarity': 0.65183259624288559}),
#  ('Functional (mathematics)',
#   'Axiomatic system',
#   {'similarity': 0.050571515164414653}),
#  ('Line (geometry)', 'Curvature', {'similarity': 0.14001558384901111}),
#  ('Trigonometry', 'Point (geometry)', {'similarity': 0.1036201489372218}),
#  ('Empirical evidence',
#   'Maintenance (technical)',
#   {'similarity': 0.054497999601114858}),
#  ('Frame of reference',
#   'Invertible matrix',
#   {'similarity': 0.042300882498193325}),
#  ('Scalar (mathematics)',
#   'Artificial intelligence',
#   {'similarity': 0.054276710472525282}),
#  ('Variable (mathematics)', 'Scientist', {'similarity': 0.087413529047276187}),
#  ('Measure (mathematics)',
#   'Symbol (formal)',
#   {'similarity': 0.018878209191237727}),
#  ('Probability theory',
#   'Linear function',
#   {'similarity': 0.038557958129336656}),
#  ('Structure', 'Quantum mechanics', {'similarity': 0.10013636636677463}),
#  ('Engineering', 'Area', {'similarity': 0.047036624703092896}),
#  ('Matrix multiplication', 'Jacques Hadamard', {'similarity': 0.0}),
#  ('Norm (mathematics)', 'Graph theory', {'similarity': 0.061032970703149392}),
#  ('Glossary of engineering',
#   'Two-dimensional space',
#   {'similarity': 0.037785141202087459}),
#  ('Unitary operator', 'Engineering', {'similarity': 0.018098254715014538}),
#  ('Computer graphics', 'Mechanics', {'similarity': 0.091839071326607222}),
#  ('Soliton', 'Unitary operator', {'similarity': 0.036904431315816694}),
#  ('Expression (mathematics)',
#   'Electromagnetism',
#   {'similarity': 0.041757443702350849}),
#  ('Giuseppe Peano',
#   'Scalar (mathematics)',
#   {'similarity': 0.052931469171777636}),
#  ('Latin', 'Variable (mathematics)', {'similarity': 0.080365034411969391}),
#  ('Stefan Banach', 'Jacques Hadamard', {'similarity': 0.34940677865077613}),
#  ('Derivative', 'Tensor', {'similarity': 0.030325832237616816}),
#  ('Rigid body',
#   'Artificial intelligence',
#   {'similarity': 0.054569410391185146}),
#  ('Complex number', 'Euclid', {'similarity': 0.069947287983800704}),
#  ('Construction', 'Electromagnetism', {'similarity': 0.075204453343288541}),
#  ('Computer graphics',
#   'Paul Lévy (mathematician)',
#   {'similarity': 0.077220829322652451}),
#  ('Complex number', 'Randomness', {'similarity': 0.093284396287523941}),
#  ('Construction',
#   'Expression (mathematics)',
#   {'similarity': 0.062481243529348189}),
#  ('Two-dimensional space',
#   'Artificial intelligence',
#   {'similarity': 0.095739487483014377}),
#  ('Conformable matrix',
#   'Group (mathematics)',
#   {'similarity': 0.062092983275228955}),
#  ('Computer graphics',
#   'Mathematical model',
#   {'similarity': 0.18724298555346278}),
#  ('Functional (mathematics)',
#   'Complex number',
#   {'similarity': 0.16052354527712845}),
#  ('Inner product space',
#   'Function (mathematics)',
#   {'similarity': 0.10705068112201714}),
#  ('Engineering', 'Space (mathematics)', {'similarity': 0.045110934388689378}),
#  ('Linear algebra',
#   'Group (mathematics)',
#   {'similarity': 0.14714094694757127}),
#  ('Applied science',
#   'Topological space',
#   {'similarity': 0.027207737314075699}),
#  ('Mathematical sciences', 'Flat (geometry)', {'similarity': 0.0}),
#  ('Matrix calculus',
#   'Module homomorphism',
#   {'similarity': 0.049062370825439273}),
#  ('Probability theory', 'Sociology', {'similarity': 0.087996546142127999}),
#  ('Orthonormal basis',
#   'Graph of a function',
#   {'similarity': 0.050334884225887569}),
#  ('Function space', 'Applied science', {'similarity': 0.018599268272356587}),
#  ('Material',
#   'Singularity (mathematics)',
#   {'similarity': 0.084217498703030899}),
#  ('Field (mathematics)', 'Polynomial', {'similarity': 0.0}),
#  ('Linear regression', 'Material', {'similarity': 0.070921907467386733}),
#  ('Incidence geometry', 'Earth science', {'similarity': 0.037168770225595005}),
#  ('Row and column vectors',
#   'Partial differential equation',
#   {'similarity': 0.042175473896619624}),
#  ('Field (mathematics)', 'Clockwise', {'similarity': 0.0}),
#  ('Algebraic equation',
#   'Orthonormal basis',
#   {'similarity': 0.045449926857147223}),
#  ('Analytic geometry',
#   'Mathematical model',
#   {'similarity': 0.10394284279891894}),
#  ('Biology', 'Earth science', {'similarity': 0.17720540380338734}),
#  ('Abstract algebra',
#   'Differential geometry',
#   {'similarity': 0.19842606202414212}),
#  ('Mechanics', 'Module homomorphism', {'similarity': 0.022612151929618671}),
#  ('Diagonal matrix', 'If and only if', {'similarity': 0.023905039211206524}),
#  ('Invertible matrix', 'Randomness', {'similarity': 0.057110530289607962}),
#  ('If and only if', 'Construction', {'similarity': 0.037959136590619412}),
#  ('Giuseppe Peano', 'Integral', {'similarity': 0.10694946630755532}),
#  ('Stefan Banach', 'Geodesic', {'similarity': 0.11122110481762949}),
#  ('Banach space', 'Flat (geometry)', {'similarity': 0.15568599154407148}),
#  ('Statistics',
#   'Dimension (vector space)',
#   {'similarity': 0.027806258474153699}),
#  ('Scalar (mathematics)', 'Coefficient', {'similarity': 0.045052155555517254}),
#  ('Morphism', 'Rigid body', {'similarity': 0.036498624925691045}),
#  ('Number', 'Pierre de Fermat', {'similarity': 0.20069489825776443}),
#  ('Euclidean space', 'Scientist', {'similarity': 0.072015586680913443}),
#  ('Chemistry', 'Parameter', {'similarity': 0.080774667258815228}),
#  ('Ring (mathematics)',
#   'Applied mathematics',
#   {'similarity': 0.025885959923488459}),
#  ('Space (mathematics)',
#   'Euclidean geometry',
#   {'similarity': 0.28085859232723054}),
#  ('Row and column vectors',
#   'Taylor series',
#   {'similarity': 0.026524118597319114}),
#  ('Calculus of variations',
#   'Real number',
#   {'similarity': 0.10297032176201396}),
#  ('Sociology', 'Science', {'similarity': 0.38437650297420473}),
#  ('Functional (mathematics)',
#   'Social science',
#   {'similarity': 0.057711761535777534}),
#  ('Group (mathematics)',
#   'Wikipedia:Citation needed',
#   {'similarity': 0.027148782563927207}),
#  ('Functional (mathematics)',
#   'Partial differential equation',
#   {'similarity': 0.25368782587643962}),
#  ('Frigyes Riesz', 'Abstract algebra', {'similarity': 0.14309759117123499}),
#  ('Eigenvalues and eigenvectors',
#   'Surface (topology)',
#   {'similarity': 0.12161350378668288}),
#  ('Exponential function',
#   'Partial differential equation',
#   {'similarity': 0.13947654030327922}),
#  ('Classical mechanics', 'Physics', {'similarity': 0.50415440315112181}),
#  ('Political science',
#   'Origin (mathematics)',
#   {'similarity': 0.031310411266025115}),
#  ('Computer science',
#   'Proportionality (mathematics)',
#   {'similarity': 0.0042178234786641603}),
#  ('Analytic geometry', 'Vector space', {'similarity': 0.25070711340572915}),
#  ('Invertible matrix', 'Physics', {'similarity': 0.055898893750664778}),
#  ('Polynomial', 'Vector space', {'similarity': 0.17652566180728543}),
#  ('Expression (mathematics)',
#   'Frame of reference',
#   {'similarity': 0.054220939989537385}),
#  ('Ancient Greek', 'Ring (mathematics)', {'similarity': 0.032658751015862984}),
#  ('Translation (geometry)', 'Physics', {'similarity': 0.055181682386467701}),
#  ('Computer science', 'Euclid', {'similarity': 0.041459469314259645}),
#  ('Morphism', 'Conformable matrix', {'similarity': 0.028858898711817564}),
#  ('Trigonometry', 'Line (geometry)', {'similarity': 0.099692013661375964}),
#  ('Active and passive transformation',
#   'Eigenvalues and eigenvectors',
#   {'similarity': 0.31032048775011428}),
#  ('Morphism', 'Mechanics', {'similarity': 0.062968435275104331}),
#  ('Frame of reference', 'System', {'similarity': 0.15779843652542958}),
#  ('Sociology', 'Clockwise', {'similarity': 0.08645068775338316}),
#  ('Scientist', 'Finite element method', {'similarity': 0.12974229191949163}),
#  ('Process', 'Rational number', {'similarity': 0.0}),
#  ('Constant term', 'Sociology', {'similarity': 0.031904012684862461}),
#  ('Computer science',
#   'Algebraic equation',
#   {'similarity': 0.057186497465191534}),
#  ('Scalar (mathematics)',
#   'Numerical analysis',
#   {'similarity': 0.091735275606117259}),
#  ('Position (vector)',
#   'Module (mathematics)',
#   {'similarity': 0.15699768879104659}),
#  ('Measure (mathematics)', 'Chemistry', {'similarity': 0.065755241394917188}),
#  ('Area', 'Language of mathematics', {'similarity': 0.099922083005536358}),
#  ('Volume', 'Rotation matrix', {'similarity': 0.035977335615379656}),
#  ('Mathematics', 'Higher-order function', {'similarity': 0.12161508791094586}),
#  ('Matrix addition', 'Banach space', {'similarity': 0.068263327349045277}),
#  ('Latin', 'Economist', {'similarity': 0.060179780953145495}),
#  ('Engineer', 'Computer science', {'similarity': 0.24756044099023691}),
#  ('Complex number', 'Linear equation', {'similarity': 0.24691445858665431}),
#  ('Mathematical analysis', 'PageRank', {'similarity': 0.095383634796473993}),
#  ('Vito Volterra', 'Linear regression', {'similarity': 0.064527624736077094}),
#  ('Mathematician',
#   'Finite element method',
#   {'similarity': 0.14931721073155754}),
#  ('Euclidean geometry', 'Vito Volterra', {'similarity': 0.12294537672337939}),
#  ('Finite element method', 'Euclid', {'similarity': 0.11469434054584142}),
#  ('Exponential function', 'Dimension', {'similarity': 0.097203813254383542}),
#  ('Linear map', 'Incidence geometry', {'similarity': 0.1203098366827096}),
#  ('If and only if', 'Electromagnetism', {'similarity': 0.041464045926541376}),
#  ('0', 'Dimension', {'similarity': 0.11545754032248408}),
#  ('List of geometers', 'Lwów School of Mathematics', {'similarity': 0.0}),
#  ('Electromagnetism', 'Graph theory', {'similarity': 0.068403816672310422}),
#  ('Equation',
#   'Paul Lévy (mathematician)',
#   {'similarity': 0.049879328519040568}),
#  ('PageRank', 'Geodesic', {'similarity': 0.057826911609207325}),
#  ('Giuseppe Peano',
#   'Empirical evidence',
#   {'similarity': 0.046995382893231352}),
#  ('PageRank', 'Social science', {'similarity': 0.11267460798099871}),
#  ('Rectangle', 'If and only if', {'similarity': 0.050115153877820263}),
#  ('Module homomorphism',
#   'Space (mathematics)',
#   {'similarity': 0.064255837320464762}),
#  ('Partial differential equation',
#   'Affine geometry',
#   {'similarity': 0.06883102177760328}),
#  ('Dimension',
#   'Reflection (mathematics)',
#   {'similarity': 0.13470994283338347}),
#  ('Position (vector)', 'Banach space', {'similarity': 0.23386808806608819}),
#  ('Mathematical sciences', 'Coordinate-free', {'similarity': 0.0}),
#  ('Geodesic', 'Linearization', {'similarity': 0.12136153306137526}),
#  ('Orthonormal basis', 'Length', {'similarity': 0.03004918388995894}),
#  ('Wikipedia:Citation needed',
#   'Norm (mathematics)',
#   {'similarity': 0.013296305967401742}),
#  ('Group (mathematics)',
#   'Conformable matrix',
#   {'similarity': 0.062092983275228955}),
#  ('Transformation matrix',
#   'Euclidean space',
#   {'similarity': 0.27319394791802387}),
#  ('Equation',
#   'Outline of physical science',
#   {'similarity': 0.075333121305411699}),
#  ('Metric (mathematics)', 'Poland', {'similarity': 0.057960279621615908}),
#  ('Mathematician', 'Soliton', {'similarity': 0.11466229164268667}),
#  ('Analytic geometry', 'Physicist', {'similarity': 0.068825162165998779}),
#  ('Coefficient', 'Number', {'similarity': 0.11233387424132302}),
#  ('Function composition',
#   'Inner product space',
#   {'similarity': 0.082834483061162256}),
#  ('Unitary operator',
#   'Numerical analysis',
#   {'similarity': 0.044183923407049457}),
#  ('Paul Lévy (mathematician)',
#   'Scientist',
#   {'similarity': 0.15571332267835547}),
#  ('Orthonormal basis',
#   'Module (mathematics)',
#   {'similarity': 0.083303802607710378}),
#  ('Topological space',
#   'Applied mathematics',
#   {'similarity': 0.021578328156975541}),
#  ('Electromagnetism',
#   'Module homomorphism',
#   {'similarity': 0.019910482140562631}),
#  ('Determinant', 'Curvature', {'similarity': 0.08926549975349593}),
#  ('Plane (geometry)',
#   'Pierre de Fermat',
#   {'similarity': 0.072631493529578664}),
#  ('Stochastic matrix', 'Randomness', {'similarity': 0.21062786577151271}),
#  ('Process', 'Dynamical system', {'similarity': 0.0}),
#  ('Expression (mathematics)',
#   'Scientist',
#   {'similarity': 0.045904184294456502}),
#  ('Function composition',
#   'Group (mathematics)',
#   {'similarity': 0.27568947521446224}),
#  ('Coordinate-free', 'PageRank', {'similarity': 0.035620040634900797}),
#  ('Trigonometry', 'Social science', {'similarity': 0.089654412310730597}),
#  ('Taylor series', 'Frigyes Riesz', {'similarity': 0.083289593013400776}),
#  ('Coordinate-free',
#   'Partial differential equation',
#   {'similarity': 0.11657694233466798}),
#  ('Parameter', 'Chaos theory', {'similarity': 0.16114455446541356}),
#  ('Abstract algebra',
#   'Outline of physical science',
#   {'similarity': 0.10471936188758806}),
#  ('Category of modules',
#   'Invertible matrix',
#   {'similarity': 0.050001230850771357}),
#  ('Political science',
#   'Operations research',
#   {'similarity': 0.31223397942600073}),
#  ('Economics', 'Linearization', {'similarity': 0.14542506185207799}),
#  ('Euclidean space',
#   'Invertible matrix',
#   {'similarity': 0.078032781142787624}),
#  ('Topological manifold', 'Row and column vectors', {'similarity': 0.0}),
#  ('Force', 'Pierre de Fermat', {'similarity': 0.064392405921739726}),
#  ('Real number', 'Field (mathematics)', {'similarity': 0.0}),
#  ('Jacques Hadamard', 'Flat (geometry)', {'similarity': 0.046721685781795211}),
#  ('Image compression', 'Dimension', {'similarity': 0.0}),
#  ('Line (geometry)',
#   'Transformation matrix',
#   {'similarity': 0.17787170179189654}),
#  ('Function space', 'Endomorphism', {'similarity': 0.48773730460152787}),
#  ('Orthonormal basis',
#   'Maurice René Fréchet',
#   {'similarity': 0.067773182860647638}),
#  ('Dimension', 'Higher-order function', {'similarity': 0.055757906518851888}),
#  ('Psychology', 'Paul Lévy (mathematician)', {'similarity': 0.0}),
#  ('Partial differential equation',
#   'Stefan Banach',
#   {'similarity': 0.09436601684744915}),
#  ('Eigenvalues and eigenvectors',
#   'Metric (mathematics)',
#   {'similarity': 0.12693551243486401}),
#  ('System of linear equations',
#   'Dynamical system',
#   {'similarity': 0.35807188918857702}),
#  ('Curvature', 'Graph of a function', {'similarity': 0.10286926122230455}),
#  ('Geometry', 'Three-dimensional space', {'similarity': 0.27190368773863732}),
#  ('Position (vector)', 'Science', {'similarity': 0.072357028004772103}),
#  ('Structure',
#   'Functional (mathematics)',
#   {'similarity': 0.052835636816885086}),
#  ('Three-dimensional space', 'Area', {'similarity': 0.19162810761183757}),
#  ('Complex number', 'Determinant', {'similarity': 0.20584505371077241}),
#  ('Measure (mathematics)',
#   'Paul Lévy (mathematician)',
#   {'similarity': 0.12438689919063114}),
#  ('Length', 'Category theory', {'similarity': 0.040479841266134152}),
#  ('Axiom', 'Three-dimensional space', {'similarity': 0.10591513062225943}),
#  ('Complex number', 'Design', {'similarity': 0.049058475396534247}),
#  ('Graph of a function',
#   'Row and column vectors',
#   {'similarity': 0.036471555296397541}),
#  ('Earth science',
#   'Proportionality (mathematics)',
#   {'similarity': 0.0056638574678879745}),
#  ('Linear equation', 'Geodesic', {'similarity': 0.22060507771954255}),
#  ('Dimension (vector space)',
#   'Category of modules',
#   {'similarity': 0.18294561248107219}),
#  ('Conformable matrix',
#   'Complex number',
#   {'similarity': 0.067756880929479416}),
#  ('Endomorphism',
#   'Dimension (vector space)',
#   {'similarity': 0.30140407816294101}),
#  ('Plane (geometry)', 'Construction', {'similarity': 0.07091656815191516}),
#  ('Structure', 'Primitive notion', {'similarity': 0.01833852371096063}),
#  ('Natural science', 'Symbol (formal)', {'similarity': 0.072886273243343652}),
#  ('Taylor series',
#   'System of linear equations',
#   {'similarity': 0.11449991439727668}),
#  ('Module (mathematics)',
#   'Three-dimensional space',
#   {'similarity': 0.11610199495773897}),
#  ('Curvature', 'Mathematical analysis', {'similarity': 0.087408318758325693}),
#  ('Higher-order function',
#   'Three-dimensional space',
#   {'similarity': 0.0894026454322219}),
#  ('Module homomorphism',
#   "Euclid's Elements",
#   {'similarity': 0.026720170973751466}),
#  ('Field (mathematics)', 'Statistics', {'similarity': 0.0}),
#  ("Euclid's Elements", 'Vector space', {'similarity': 0.079606076767026065}),
#  ('Numerical analysis',
#   'Diagonal matrix',
#   {'similarity': 0.12093097510902245}),
#  ('Determinant', 'Abstract algebra', {'similarity': 0.13764542465059298}),
#  ('Space (mathematics)',
#   'Mathematical model',
#   {'similarity': 0.098024515390696842}),
#  ('Biology', 'Integral', {'similarity': 0.081919667234950755}),
#  ('Statistician',
#   'Measure (mathematics)',
#   {'similarity': 0.02125815750596468}),
#  ('Functional (mathematics)',
#   'Construction',
#   {'similarity': 0.038147699928859663}),
#  ('Axiom', 'Two-dimensional space', {'similarity': 0.11397265038444028}),
#  ('Graph theory', 'Group (mathematics)', {'similarity': 0.074781115522483704}),
#  ('Force', 'Orthonormal basis', {'similarity': 0.044574749521126}),
#  ('Continuous function', 'Taylor series', {'similarity': 0.35135869009160514}),
#  ('Empirical evidence',
#   'Function composition',
#   {'similarity': 0.0184209695133014}),
#  ('Economics', 'Linear regression', {'similarity': 0.18357986248305119}),
#  ('System', 'Unitary operator', {'similarity': 0.041804357858271149}),
#  ('Integral equation', 'Engineering', {'similarity': 0.046744865991877591}),
#  ('Term (logic)', 'Economist', {'similarity': 0.028195691931076305}),
#  ('Linear system', 'Rigid body dynamics', {'similarity': 0.15154615742603839}),
#  ('Position (vector)', 'Term (logic)', {'similarity': 0.12375932642721914}),
#  ('Image compression', 'Expression (mathematics)', {'similarity': 0.0}),
#  ('Matrix addition', 'System', {'similarity': 0.024193156538278807}),
#  ('Biology', 'Empirical evidence', {'similarity': 0.098063792837366687}),
#  ('Non-Euclidean geometry', 'Morphism', {'similarity': 0.04571260688429489}),
#  ('Machine', 'Soliton', {'similarity': 0.12575305142849555}),
#  ('Rectangle', 'Geodesic', {'similarity': 0.094497444933247826}),
#  ('Linear equation', 'Soliton', {'similarity': 0.24326826518304059}),
#  ('Matrix (mathematics)',
#   'Political science',
#   {'similarity': 0.064969614454891703}),
#  ('Machine', 'Term (logic)', {'similarity': 0.052346468578533936}),
#  ('Engineering', 'Topological space', {'similarity': 0.027063941571225662}),
#  ('Primitive notion', 'Innovation', {'similarity': 0.010614640534530088}),
#  ('Line (geometry)',
#   'Graph of a function',
#   {'similarity': 0.14333226449177777}),
#  ('Linear algebra', 'Motion (geometry)', {'similarity': 0.0}),
#  ('Glossary of computer graphics', 'Rational number', {'similarity': 0.0}),
#  ('Transformation matrix', 'Integral', {'similarity': 0.071049131545839264}),
#  ('Topological manifold', 'Quantum electrodynamics', {'similarity': 0.0}),
#  ('Dimension', 'Taylor series', {'similarity': 0.078848950237563581}),
#  ('Linear map', 'Graph of a function', {'similarity': 0.081924355871772908}),
#  ('Trigonometry', 'Endomorphism', {'similarity': 0.070679675219337712}),
#  ('System of linear equations',
#   'Quantum electrodynamics',
#   {'similarity': 0.13778547258591503}),
#  ('Process', 'Maintenance (technical)', {'similarity': 0.0}),
#  ('Wikipedia:Citation needed',
#   'Surface (topology)',
# ...
#  ('Field (mathematics)', 'List of engineering branches', {'similarity': 0.0}),
#  ('Fourier transform', 'Morphism', {'similarity': 0.27228214537683454}),
#  ('Finite element method',
#   'Vector space',
#   {'similarity': 0.17040782350790104}),
#  ('Statistician', 'Conformable matrix', {'similarity': 0.013030176568260212}),
#  ('Integral equation',
#   'Euclidean space',
#   {'similarity': 0.057743847150178308}),
#  ('If and only if', 'Unitary operator', {'similarity': 0.03298142301834623}),
#  ('Wikipedia:Citation needed', 'Psychology', {'similarity': 0.0}),
#  ('Quantum mechanics',
#   'Jacques Hadamard',
#   {'similarity': 0.14792038113527828}),
#  ('Rigid body dynamics',
#   'Computer graphics',
#   {'similarity': 0.069635790782786575}),
#  ('Area', 'Graph of a function', {'similarity': 0.11078143993855122}),
#  ('Probability theory',
#   'Frame of reference',
#   {'similarity': 0.054490250091006727}),
#  ('Scientist', 'Linear regression', {'similarity': 0.14118606308006071}),
#  ('Linearization', 'Term (logic)', {'similarity': 0.10432115045082478}),
#  ('Psychology', 'Integral equation', {'similarity': 0.0}),
#  ('Mathematical analysis', 'Matrix multiplication', {'similarity': 0.0}),
#  ('Optics', 'Rotation matrix', {'similarity': 0.091085602494285781}),
#  ('Poland',
#   'Proportionality (mathematics)',
#   {'similarity': 0.031583387154205431}),
#  ('Banach space', 'Matrix addition', {'similarity': 0.068263327349045277}),
#  ('Morphism', 'Symbol (formal)', {'similarity': 0.035954353288703479}),
#  ('Position (vector)', 'Trigonometry', {'similarity': 0.088942291624095018}),
#  ('Invertible matrix', 'List of geometers', {'similarity': 0.0}),
#  ('Linear combination', 'Structure', {'similarity': 0.0}),
#  ('Singularity (mathematics)',
#   'Topology',
#   {'similarity': 0.11317902026591174}),
#  ('Functional (mathematics)',
#   'If and only if',
#   {'similarity': 0.028653665533471137}),
#  ('Physics', 'Differential equation', {'similarity': 0.17912409789247727}),
#  ('Machine', 'Calculus of variations', {'similarity': 0.091750976027921261}),
#  ('Computer science', 'Dynamical system', {'similarity': 0.13784984028971495}),
#  ('Term (logic)', 'Empirical evidence', {'similarity': 0.070702644414700463}),
#  ('Scientist',
#   'Singularity (mathematics)',
#   {'similarity': 0.054266429742519058}),
#  ('Maurice René Fréchet', 'Conformable matrix', {'similarity': 0.0}),
#  ('Linear equation',
#   'Conformable matrix',
#   {'similarity': 0.015586205091914157}),
#  ('Trigonometry',
#   'Partial differential equation',
#   {'similarity': 0.093722445638200355}),
#  ('Earth science', 'Plane (geometry)', {'similarity': 0.044349328481624428}),
#  ('Module (mathematics)',
#   'Affine geometry',
#   {'similarity': 0.078253616096033499}),
#  ('Euclidean vector', '0', {'similarity': 0.11435247375849598}),
#  ('Motion (geometry)', 'Transformation (function)', {'similarity': 0.0}),
#  ('Linear equation',
#   'Mathematical model',
#   {'similarity': 0.14006007762836953}),
#  ('Glossary of computer graphics', 'Randomness', {'similarity': 0.0}),
#  ('Coordinate-free',
#   'Module (mathematics)',
#   {'similarity': 0.020594103863637692}),
#  ('Geodesic', 'Statistics', {'similarity': 0.07102867580951211}),
#  ('Computer science',
#   'Matrix (mathematics)',
#   {'similarity': 0.08370805069729495}),
#  ('Scalar (mathematics)',
#   'Diagonal matrix',
#   {'similarity': 0.21684115813726693}),
#  ('Material', 'Linear combination', {'similarity': 0.0}),
#  ('Force', 'Clockwise', {'similarity': 0.14196770422824861}),
#  ('Number', 'Quantum electrodynamics', {'similarity': 0.17934324231562307}),
#  ('Geodesic', 'Diagonal matrix', {'similarity': 0.037881396237717781}),
#  ('Euclidean geometry',
#   'Position (vector)',
#   {'similarity': 0.11680479783289366}),
#  ('Volume', 'Engineering', {'similarity': 0.024479917508620087}),
#  ('Classical mechanics', 'Structure', {'similarity': 0.092319757214150505}),
#  ('Function (mathematics)', 'Rectangle', {'similarity': 0.073251448271244093}),
#  ('Hilbert space', 'Affine geometry', {'similarity': 0.16342309746444536}),
#  ('Natural science',
#   'Proportionality (mathematics)',
#   {'similarity': 0.012538077450703252}),
#  ('Euclidean vector', 'Rational number', {'similarity': 0.084223955015414312}),
#  ('Middle Ages', 'Line (geometry)', {'similarity': 0.0}),
#  ('Translation (geometry)', 'Rectangle', {'similarity': 0.053416207517509411}),
#  ('Vito Volterra', 'Integral equation', {'similarity': 0.24181179738975739}),
#  ('Space (mathematics)', 'Derivative', {'similarity': 0.028474522404067198}),
#  ('Translation (geometry)',
#   'Derivative',
#   {'similarity': 0.0048763213631069372}),
#  ('Number', 'Topological space', {'similarity': 0.10027662047566455}),
#  ('Topological space',
#   'Rotation (mathematics)',
#   {'similarity': 0.084891279536787198}),
#  ('Mechanics', 'Image compression', {'similarity': 0.0}),
#  ('Process', 'Coefficient', {'similarity': 0.0}),
#  ('Dimension (vector space)',
#   'Sparse matrix',
#   {'similarity': 0.051832624883952176}),
#  ('Euclidean space',
#   'Functional analysis',
#   {'similarity': 0.32070671906617343}),
#  ('Functional (mathematics)',
#   'Maurice René Fréchet',
#   {'similarity': 0.1194272465563702}),
#  ('Frigyes Riesz', 'Natural science', {'similarity': 0.178657441176899}),
#  ('Matrix multiplication', "Euclid's Elements", {'similarity': 0.0}),
#  ('Statistician', 'Hilbert space', {'similarity': 0.052370930218491478}),
#  ('Singularity (mathematics)',
#   'Transformation matrix',
#   {'similarity': 0.094353880105078364}),
#  ('Point (geometry)',
#   'Empirical evidence',
#   {'similarity': 0.039189807441685036}),
#  ('Dimension (vector space)',
#   'Norm (mathematics)',
#   {'similarity': 0.42966288476761877}),
#  ('PageRank', 'Soliton', {'similarity': 0.060556034284962895}),
#  ('0', 'Derivative', {'similarity': 0.049336197037648716}),
#  ('Giuseppe Peano', 'Nonlinear system', {'similarity': 0.086497457748023171}),
#  ('Tensor', 'Integral equation', {'similarity': 0.083791283282955237}),
#  ('Dimension', 'Organization', {'similarity': 0.058363778327981772}),
#  ('Middle Ages', 'Banach space', {'similarity': 0.0}),
#  ('Function (mathematics)',
#   'Calculus of variations',
#   {'similarity': 0.47075500140520921}),
#  ('Singularity (mathematics)',
#   'Derivative',
#   {'similarity': 0.041808422742657475}),
#  ('Variable (mathematics)',
#   'Paul Lévy (mathematician)',
#   {'similarity': 0.061563420232929995}),
#  ('Algebraic equation',
#   'Reflection (mathematics)',
#   {'similarity': 0.023216317207616386}),
#  ('Biology', 'Topological manifold', {'similarity': 0.0}),
#  ('Coordinate-free', 'Position (vector)', {'similarity': 0.10919080812395644}),
#  ('Rotation matrix', 'Stochastic matrix', {'similarity': 0.26151124097523848}),
#  ('Frigyes Riesz', 'Political science', {'similarity': 0.17127854658927455}),
#  ('Lwów School of Mathematics', 'Area', {'similarity': 0.051524430636852796}),
#  ('Linear combination', 'Volume', {'similarity': 0.0}),
#  ('Term (logic)', 'Polynomial', {'similarity': 0.23437308636452922}),
#  ('Organization',
#   'Proportionality (mathematics)',
#   {'similarity': 0.015944845966299463}),
#  ('Vito Volterra', 'Taylor series', {'similarity': 0.084915797692017056}),
#  ('Giuseppe Peano',
#   'Surface (topology)',
#   {'similarity': 0.059477669151816806}),
#  ('Physicist',
#   'Paul Lévy (mathematician)',
#   {'similarity': 0.081805768300526507}),
#  ('Module homomorphism',
#   'Rational number',
#   {'similarity': 0.058599315311098334}),
#  ('Transformation matrix', 'Morphism', {'similarity': 0.083926122814138804}),
#  ('Integral equation',
#   'Coordinate-free',
#   {'similarity': 0.096664550541287475}),
#  ('Maintenance (technical)',
#   'Empirical evidence',
#   {'similarity': 0.054497999601114858}),
#  ('Motion (geometry)', 'Module (mathematics)', {'similarity': 0.0}),
#  ('Real number', 'Engineering', {'similarity': 0.064588693406927092}),
#  ('Social science', 'Vector space', {'similarity': 0.053273357303094244}),
#  ('Coordinate-free',
#   'Integral equation',
#   {'similarity': 0.096664550541287475}),
#  ('Rigid body dynamics',
#   'Three-dimensional space',
#   {'similarity': 0.17884554434965802}),
#  ('Optics', 'Electromagnetism', {'similarity': 0.26155939467086703}),
#  ('0', 'Machine', {'similarity': 0.12137538692866541}),
#  ('Quantum mechanics',
#   'Applied science',
#   {'similarity': 0.092257072977780505}),
#  ('Transformation matrix', 'Science', {'similarity': 0.06439419058315797}),
#  ('Ancient Greek',
#   'Translation (geometry)',
#   {'similarity': 0.050034654405020598}),
#  ('Linear equation', 'Rectangle', {'similarity': 0.15340293401528199}),
#  ('Function space',
#   'Paul Lévy (mathematician)',
#   {'similarity': 0.014318069497539814}),
#  ('Term (logic)',
#   'Non-Euclidean geometry',
#   {'similarity': 0.070211850160458306}),
#  ('Axiomatic system', 'System', {'similarity': 0.32944030003864677}),
#  ('Engineering', 'Conformable matrix', {'similarity': 0.017838667909958673}),
#  ('Outline of physical science',
#   'Polynomial',
#   {'similarity': 0.029322364410394493}),
#  ('Banach space', 'Rigid body', {'similarity': 0.057472828562128403}),
#  ('Mechanics', 'Translation (geometry)', {'similarity': 0.049431390594421983}),
#  ('Electromagnetism',
#   'Outline of physical science',
#   {'similarity': 0.15243152452161524}),
#  ('Force', 'Category of modules', {'similarity': 0.032958159489115263}),
#  ('Applied mathematics', 'Soliton', {'similarity': 0.064730120778001748}),
#  ('Field (mathematics)', 'Axiom', {'similarity': 0.0}),
#  ('Poland', 'Force', {'similarity': 0.22411952629562387}),
#  ('Rotation (mathematics)',
#   'Projective geometry',
#   {'similarity': 0.16112486077852309}),
#  ('Design', 'Differential geometry', {'similarity': 0.038441078705093647}),
#  ('Probability', 'Finite element method', {'similarity': 0.12647731334261433}),
#  ('Language of mathematics',
#   'Transformation matrix',
#   {'similarity': 0.054109967908911955}),
#  ('Fourier transform',
#   'Space (mathematics)',
#   {'similarity': 0.14371503456026605}),
#  ('Glossary of computer graphics',
#   'Module (mathematics)',
#   {'similarity': 0.0}),
#  ('Maurice René Fréchet',
#   'Euclidean space',
#   {'similarity': 0.12963706905908887}),
#  ('Proportionality (mathematics)', 'Process', {'similarity': 0.0}),
#  ('Statistics', 'Variable (mathematics)', {'similarity': 0.18036181944504873}),
#  ('Maintenance (technical)',
#   'Calculus of variations',
#   {'similarity': 0.092254904543407568}),
#  ('Dimension', 'Structure', {'similarity': 0.11522299920967877}),
#  ('Inner product space', 'System', {'similarity': 0.029399041003442962}),
#  ('Polynomial', 'Sparse matrix', {'similarity': 0.078525895787976488}),
#  ('Integral equation', 'Flat (geometry)', {'similarity': 0.14158240019915849}),
#  ('List of engineering branches',
#   'Transformation matrix',
#   {'similarity': 0.015158953956175164}),
#  ('Maurice René Fréchet', 'Trigonometry', {'similarity': 0.10861669733176584}),
#  ('Coordinate-free', 'Morphism', {'similarity': 0.018664577434065889}),
#  ('Pierre de Fermat', 'Axiom', {'similarity': 0.11462325797668875}),
#  ('Origin (mathematics)',
#   'Empirical evidence',
#   {'similarity': 0.027226582252722942}),
#  ('Endomorphism', 'Poland', {'similarity': 0.08081816794258305}),
#  ('Continuous function',
#   'Affine geometry',
#   {'similarity': 0.091313465869352115}),
#  ("Euclid's Elements",
#   'Linear equation',
#   {'similarity': 0.072867704698169389}),
#  ('Classical mechanics',
#   'Affine geometry',
#   {'similarity': 0.073669734938236003}),
#  ('Tensor', 'Innovation', {'similarity': 0.040265724199961106}),
#  ('Finite element method',
#   'Organization',
#   {'similarity': 0.10288962242091661}),
#  ('Topology', 'Determinant', {'similarity': 0.094306502753668323}),
#  ('Optics', 'Paul Lévy (mathematician)', {'similarity': 0.055378197747926731}),
#  ('Axiomatic system', 'Number', {'similarity': 0.20868296540927597}),
#  ('Social science', 'Stochastic matrix', {'similarity': 0.10363837217063969}),
#  ('Soliton', 'Expression (mathematics)', {'similarity': 0.044875733483009307}),
#  ('Functional (mathematics)',
#   'Rotation (mathematics)',
#   {'similarity': 0.032527253305820139}),
#  ('Transformation (function)',
#   'Abstract algebra',
#   {'similarity': 0.092473388445196675}),
#  ('Coordinate system',
#   'Unitary operator',
#   {'similarity': 0.025745056659414463}),
#  ('Lwów School of Mathematics',
#   'Wikipedia:Citation needed',
#   {'similarity': 0.037391221980042369}),
#  ('Equation', 'Structure', {'similarity': 0.068894046976618689}),
#  ('Applied mathematics', 'Statistics', {'similarity': 0.11312634698648498}),
#  ('Topology', 'Non-Euclidean geometry', {'similarity': 0.13822691044688731}),
#  ('Jacques Hadamard',
#   'Position (vector)',
#   {'similarity': 0.087400393455155309}),
#  ('Singularity (mathematics)', 'Poland', {'similarity': 0.091732560819138984}),
#  ('Earth science',
#   'Functional (mathematics)',
#   {'similarity': 0.022295315832486257}),
#  ('Mathematical model',
#   'Giuseppe Peano',
#   {'similarity': 0.069997897804841253}),
#  ('Norm (mathematics)',
#   'Differential equation',
#   {'similarity': 0.037939671681967262}),
#  ('Active and passive transformation',
#   'Morphism',
#   {'similarity': 0.036603550137453991}),
#  ('List of engineering branches',
#   'Physicist',
#   {'similarity': 0.27866725425157768}),
#  ('Linear function',
#   'Ring (mathematics)',
#   {'similarity': 0.068452952715185561}),
#  ('Frigyes Riesz',
#   'Dimension (vector space)',
#   {'similarity': 0.020136671076014329}),
#  ('Ring (mathematics)', 'Glossary of computer graphics', {'similarity': 0.0}),
#  ('Continuous function', 'Morphism', {'similarity': 0.44723419570567691}),
#  ('Norm (mathematics)', 'Matrix multiplication', {'similarity': 0.0}),
#  ('Force', 'Fourier series', {'similarity': 0.045388451806748706}),
#  ('Numerical analysis', 'Morphism', {'similarity': 0.083422668693880278}),
#  ('Flat (geometry)', 'Organization', {'similarity': 0.018277712357968354}),
#  ('Chemistry', 'Rigid body dynamics', {'similarity': 0.091048307294216396}),
#  ('System', 'Constant term', {'similarity': 0.031220791833477139}),
#  ('Matrix calculus', 'Social science', {'similarity': 0.064895996880705173}),
#  ('Taylor series',
#   'Space (mathematics)',
#   {'similarity': 0.078425812041088075}),
#  ('Biology', 'Function composition', {'similarity': 0.06523185985244509}),
#  ('Sparse matrix', 'Linear equation', {'similarity': 0.10126465665105644}),
#  ('Axiom', 'Linear regression', {'similarity': 0.10264481238654709}),
#  ('Length', 'Linear function', {'similarity': 0.042266398183501502}),
#  ('Ring (mathematics)', 'Mathematician', {'similarity': 0.038233858734862042}),
#  ('Incidence geometry', 'Economist', {'similarity': 0.03034632887276241}),
#  ('Mathematical sciences', 'Topological manifold', {'similarity': 0.0}),
#  ('Equation', 'Axiomatic system', {'similarity': 0.10503564540450379}),
#  ('Coefficient', 'Topological manifold', {'similarity': 0.0}),
#  ('Psychology', 'Pierre de Fermat', {'similarity': 0.0}),
#  ('Mathematical model', 'Mechanics', {'similarity': 0.17728133263815776}),
#  ('Expression (mathematics)',
#   'Quantum mechanics',
#   {'similarity': 0.08060757603285286}),
#  ('Three-dimensional space',
#   'Integral equation',
#   {'similarity': 0.25691834925869628}),
#  ('Force', 'Process', {'similarity': 0.0}),
#  ('Position (vector)', 'Geodesic', {'similarity': 0.28453681628045291}),
#  ('Operations research',
#   'Sparse matrix',
#   {'similarity': 0.087051859002842041}),
#  ('Tensor', 'Geodesic', {'similarity': 0.13410615470105897}),
#  ('Function composition', 'Mathematical sciences', {'similarity': 0.0}),
#  ('Image compression', 'Axiomatic system', {'similarity': 0.0}),
#  ('Quantum electrodynamics',
#   'Polynomial',
#   {'similarity': 0.074941153710474329}),
#  ('If and only if', 'Innovation', {'similarity': 0.02461437497695489}),
#  ('Transformation matrix', 'Geodesic', {'similarity': 0.12906517239795992}),
#  ('System of linear equations',
#   'Module homomorphism',
#   {'similarity': 0.068309770918514312}),
#  ('Module homomorphism', 'Material', {'similarity': 0.020005336211944585}),
#  ('Continuous function',
#   'Wikipedia:Citation needed',
#   {'similarity': 0.026834973348954974}),
#  ('René Descartes', 'Trigonometry', {'similarity': 0.070967590598992811}),
#  ('Euclidean geometry',
#   'Conformable matrix',
#   {'similarity': 0.019563540723682677}),
#  ('Randomness', 'Flat (geometry)', {'similarity': 0.024240265043553554}),
#  ...]

# %%
edges_list = []
nodes_list = []
for i in docs:
    nodes_list.append(i[0])
    nodes_list.append(i[1])
    edge = (i[0], i[1], {'similarity': docs.get(i)})
    edges_list.append(edge)

# %%
G.add_edges_from(docs)
